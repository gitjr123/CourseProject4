# %% [markdown]
# ### __9) Results__

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt

# %%
data_dir = 'C:/Users/tgdreju4/OneDrive - Swisscom/EPFL/Notebooks/04ML/swissroads/'

# %%
# Load the result file
df = pd.read_csv(data_dir + 'data.csv', index_col=0)
df
# Out:
#            model  test accuracy
# 0            knn       0.840000
# 1  decision tree       0.900000
# 2       Logistic       0.940000
# 3     smv linear       0.940000
# 4        smv rbf       0.940000
# 5  random forest       0.940000
# 6     1-layer nn       0.920863
# 7     2-layer nn       0.928058
# 8   Conv network       0.240000

# %% [markdown]
# #### Plot bar chart with all results

# %%
ax = df.plot.barh(x='model' , y='test accuracy', rot=0,  figsize=(20 , 10))
plt.title('Image classifiers for swissroads images - Project 4')
plt.xlabel('Test accuracy')
plt.ylabel('Model')
# Out:
# Text(0, 0.5, 'Model')
